# %% [markdown]
# 8.8. Оксана поливает на подоконнике герань, фиалки и кактус. Каждый день она меняет местами правый и центральный горшки, чтобы они равномернее получали солнечные лучи. А Олег вечером переставляет центральный и левый горшочки.
#
# Напишите программу, которая выведет порядок цветков на подоконнике через N дней.
# Смоделируйте сам процесс перестановок, чтобы внутренние переменные (горшочки) в программе хранили новый порядок.

# %%
days_num = int(input()) # переменная для кол-ва дней
# изначальная расстановка цветов
left = 'герань'
center = 'фиалка'
right = 'кактус'
extra = 0 # доп. переменная для того, чтобы временно в нее класть значения других переменных, чтобы поменять местами

# пишем цикл для нужного количества дней
for i in range(1, days_num + 1):
    # действия Оксаны: смена мест правого и центрального
    extra = center # кладем в доп.переменную значение центра
    center = right # меняем местами центр и право
    right = extra # кладем значение правого в доп.переменную
    # действия Олега: смена мест центрального и левого
    extra = center # доп.переменная, равная правому, становится центром
    center = left # центр меняется местами с левым
    left = extra # левый записывается в доп.

print(left, center, right) # выводим результат
# Out:
# 10
# кактус герань фиалка

# %% [markdown]
# 8.9. Вечная классика программирования -- факториал (в математике записывается как !).
#
# Факториал -- это для числа N произведение всех чисел от 1 до N.
#
# Например,
# 5! = 1*2*3*4*5 = 120
#
# Напишите программу, вычисляющую факториал числа.

# %%
n = int(input())
x = 1
for i in range(1, n + 1):
    x *= i
print('Факториал числа', n, 'равен', x)
# Out:
# 10
# Факториал числа 10 равен 3628800

# %% [markdown]
# Рефлексия: <br>
# 8.5.: Все верно. <br>
# 8.6.: Все верно. <br>
# 8.7.: Выводила некоторые промежуточные решени (в частности, сумму делителей), также не в том месте написала условие для вывода "Некорректное число", из-за чего это выводилось бы столько раз, сколько цикл проходится. Решение не оптимально, много вложенных ифов и лишних движений. Не могу пока мыслить компактно и выдавать изящные решения.
