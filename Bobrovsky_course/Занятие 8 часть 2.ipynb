# %% [markdown]
# 8.5. Напишите программу, которая выводит все числа от 0 до 11, кроме чисел 3 и 6.

# %%
for i in range(0, 12):
    if i != 3 and i != 6:
        print(i)
# Out:
# 0
# 1
# 2
# 4
# 5
# 7
# 8
# 9
# 10
# 11

# %% [markdown]
# 8.6. Напишите программу, которая последовательно выводит числа от 1 до 50, но если число нацело делится на три, печатайте "*333*", если число делится нацело на пять, печатайте "*555*", а если число делится нацело и на три, и на пять, печатайте "*333*555*".

# %%
for i in range(1, 51):
    if i % 3 == 0 and i % 5 == 0: # сначала проверяем условие, удовлетворяющее делению и на 3, и на 5, 
        print('333555') # иначе условный оператор не будет до него доходить, потому что этb числа на 3 и на 5 тоже отдельно делятся,
    elif i % 5 == 0: # так что будет считаться, что условие выполнено
        print('555')
    elif i % 3 == 0:
        print('333')
    else:
        print(i)
# Out:
# 1
# 2
# 333
# 4
# 555
# 333
# 7
# 8
# 333
# 555
# 11
# 333
# 13
# 14
# 333555
# 16
# 17
# 333
# 19
# 555
# 333
# 22
# 23
# 333
# 555
# 26
# 333
# 28
# 29
# 333555
# 31
# 32
# 333
# 34
# 555
# 333
# 37
# 38
# 333
# 555
# 41
# 333
# 43
# 44
# 333555
# 46
# 47
# 333
# 49
# 555

# %% [markdown]
# 8.7. Оксана вычитала в астрологическом журнале очередной способ гадания любит/не любит: нумерологический.
# Надо проверить время (часы, 1-24), на которое парень назначил ей свидание, на чётность. Если результат будет нечётным, значит, не любит!
#
# Алгоритм проверки такой: надо просуммировать все натуральные делители числа, исключив 1 и само число.
#
# Например, Олег назначил Оксане свидание в 6 утра. 6 делится нацело на 2 и на 3, 2+3=5, нечётно -- не любит!

# %%
delitel = 0 # введем переменную, куда будем, проходясь по циклу, записывать натуральные делители числа
hour = int(input()) # введем переменную для ввода часа
summa = 0 # введем переменную для суммы делителей
for i in range(1, hour): # берем диапазон до hour, а не hour + 1, чтобы сразу исключить делитель, равный числу
    if hour >= 1 and hour <= 24: # зададим диапазон корректных для данной задачи чисел
        if hour % i == 0: # получаем натуральный делитель
            delitel += 1 # записываем его в переменную
            if delitel != 1: # само число мы исключили ранее, задав границы диапазона, осталось исключить делитель, равный 1
                summa += i # складываем натуральные делители числа
    else:
        print('Некорректное число') # выводим на экран в случае, если введено число за пределами данного диапащона
        
print('Сумма делителей равна:', summa) # выводим сумму натуральных делителей на экран
            
if summa % 2 == 0: # если сумма делителей получилась четная, выводим на экран, что лююит
    print('Любит!')
else: # в противном случае выводим, что не любит
    print('Не любит!')
# Out:
# 18
# Сумма делителей равна: 20
# Любит!

# %% [markdown]
# Рефлексия: <br>
# 8.1.: Все верно. <br>
# 8.2.: Все верно, так же, как в эталонном решении, только запись немного иная. <br>
# 8.3.: Посчитала среднее в цикле и не формулой деления на (m - n + 1), а просто делением на m, посчитав, что количество слагаемых всегда будет равно последней границе диапазона, так как специфического шага в условии не было, а значит, он по умолчанию равен 1. <br>
# 8.4.: Верно, только в условии я указала, что остаток от деления числа на 2 должен быть не равен нулю, а не то, что он должен быть равен 1.
