# %% [markdown]
# <b>Задание.<b/>
# Примените 5-7 рекомендаций PEP 8 к какому-нибудь своему коду из предыдущих занятий, покажите, что в нём улучшили.

# %% [markdown]
# 1) Занятие 9 часть 3: недостаточное кол-во отступов, на два меньше. Сделала достаточное.
#
# 2) Занятие 9 часть 3: из-за комментария максимальная длина строки не ограничивается рекомендуемыми 79 символами, становится больше. Перенесла часть комментария на следующую строку.
#
# 3) Пишу комментарии с маленькой, а не с большой буквы.
#
# 4) Блочные комментарии часто начинаются не с тем же кол-вом пробелов, что и сам блок, а с начала строки.
#
# 5) Часто грешу встроенными комментариями, то есть комментариями на той же строке, что и код. Сказано, что это излишне, но я делаю это для себя, чтобы не забыть логику решения.
